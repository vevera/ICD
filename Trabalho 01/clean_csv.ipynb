# %%
import pandas as pd

# %% [markdown]
# *Como pretendo trabalhar algum algoritmo de machine learning em cima do atributo tweet que é o texto em si, a parte de limpeza ficou um pouco mais simples*.

# %%
csv = pd.read_csv("lei_rouanet_final.csv")

# %%
csv.dropna()
# Out:
#                                              id  \
# 0      @JOAOROS361222122021-12-05T23:16:49.000Z
# 1          @tgjesus19842021-12-05T22:53:32.000Z
# 2             @Dudao_132021-12-05T22:21:34.000Z
# 3         @little_thigh2021-12-05T22:18:42.000Z
# 4            @marce77072021-12-05T21:47:50.000Z
# ...                                         ...
# 16460   @S2EstelaMaiaS22020-08-24T11:41:06.000Z
# 16461  @MrciaGa908481442020-08-24T11:38:19.000Z
# 16462     @WilsonBento82020-08-24T11:34:18.000Z
# 16463  @Rosemei649079042020-08-24T11:28:27.000Z
# 16464           @AP30092020-08-24T11:27:59.000Z
#
#                                  nome            arroba  \
# 0                          JOAO ROSSI  @JOAOROS36122212
# 1            tiago goncalvis de jesus      @tgjesus1984
# 2                               Dudão         @Dudao_13
# 3                       Anticomunista     @little_thigh
# 4                            Marcello        @marce7707
# ...

# %%
csv.apply(lambda x: x.astype(str).str.lower())
# Out:
#                                              id  \
# 0      @joaoros361222122021-12-05t23:16:49.000z
# 1          @tgjesus19842021-12-05t22:53:32.000z
# 2             @dudao_132021-12-05t22:21:34.000z
# 3         @little_thigh2021-12-05t22:18:42.000z
# 4            @marce77072021-12-05t21:47:50.000z
# ...                                         ...
# 16460   @s2estelamaias22020-08-24t11:41:06.000z
# 16461  @mrciaga908481442020-08-24t11:38:19.000z
# 16462     @wilsonbento82020-08-24t11:34:18.000z
# 16463  @rosemei649079042020-08-24t11:28:27.000z
# 16464           @ap30092020-08-24t11:27:59.000z
#
#                                  nome            arroba  \
# 0                          joao rossi  @joaoros36122212
# 1            tiago goncalvis de jesus      @tgjesus1984
# 2                               dudão         @dudao_13
# 3                       anticomunista     @little_thigh
# 4                            marcello        @marce7707
# ...

# %%
csv.describe()
# Out:
#                 com           ret         likes
# count  16465.000000  16465.000000  16465.000000
# mean       0.857212      4.444276     20.710234
# std       12.871254     75.492130    368.121091
# min        0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000
# max      642.000000   4500.000000  24400.000000

# %% [markdown]
# #### Removendo linhas com o mesmo conteudo (tweet)
# ###### Para o algoritmo que tenho em mente textos repedidos não ajudam em nada.

# %%
csv = csv.drop_duplicates(subset=["tweet"], keep="first")

# %%
csv.describe()
# Out:
#                 com           ret         likes
# count  15285.000000  15285.000000  15285.000000
# mean       0.811384      3.727707     17.764148
# std       12.677629     60.379727    291.522262
# min        0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000
# max      642.000000   3000.000000  12000.000000

# %%
csv2 = csv.drop(csv[csv.tweet.map(len) < 5].index)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
list(csv.tweet)
# Out:
# ['Zé Ruela você aparenta uns 90 anos,está acabado, e agora tem trabalhar, acabou a lei rouanet.',
#  'É amigo esse cidadão nao tem apartamento funcional,lei Rouanet, educação de qualidade,medico ,dentista e ele pagou por tudo isso...',
#  'Zélia, ele não gosta da lei Rouanet, você sabe disso. ',
#  'Quem prega esse ódio é a esquerda. O lema fascista dizia: Tudo no Estado, nada contra o Estado, e nada fora do Estado. Combina com essa esquerda caviar que adora pendurar no estado com lei Rouanet e outras mamatas. Era para ficar em casa mas no carnaval o vírus não transmite.',
#  'Isso aí é lei Rouanet.\nFies é outra coisa, tá se confundindo mano',
#  'CRIANÇA TOCAR CORPO DE HOMEM NU!!!! \n\npermitir que uma criança tocasse em um homem nu utilizou o instrumento mais comum para o financiamento cultural dirigido pelo estado: a Lei 8.313/1991, também conhecida como “Lei Rouanet”.',
# ...
